# %%
# Imports
import os
import warnings
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

warnings.simplefilter(action='ignore', category=DeprecationWarning)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def column_select(df, columns_to_select):
    selected_columns = []
    for column_name in columns_to_select:
        # Check if the column exists in the DataFrame
        if column_name in df.columns:
            # If the column exists, select it and add it to the list of selected columns
            selected_columns.append(column_name)
        else:
            # If the column does not exist, issue a warning
            print(f"Column '{column_name}' does not exist in the DataFrame.")

    # Select the columns from the DataFrame
    return df[selected_columns]

# %%
taluker = ["hc31", "hc61", "hv270", "v025"]                                                                             # 2014
# ha40 is bmi which is used as target feature
islam = ["v012", "v025", "hv270", "v106", "v404", "v714","v213", "v201", "v701", "v113", "v116","v130", 'v161', 'ha40']        # 2014

# dropped ha66, always NaN

# %%
BDHS_14_child = pd.read_stata("./data/2014/BDKR72FL.DTA")
BDHS_14_household = pd.read_stata("./data/2014/BDHR72FL.DTA")
BDHS_14_individual = pd.read_stata("./data/2014/BDIR72FL.DTA")
BDHS_14_hh_member = pd.read_stata("./data/2014/BDPR72FL.DTA")
BDHS_14 = pd.concat([BDHS_14_child,BDHS_14_household, BDHS_14_individual, BDHS_14_hh_member], axis =1)

# %%
# Define the bins and labels
bins = [0, 1850, 2490, float('inf')]
labels = ['underweight', 'normal', 'obese']

age_bins = [15, 20, 30, 40, 50]
age_labels = ['15-19', '20-29', '30-39', '40-49']

wealth_bins = [-float('inf'), 'poorer', 'middle', 'richer', float('inf')]
wealth_labels = ['poor', 'middle', 'rich']

children_bins = [-1, 0, 2, 4, 20]
children_labels = ['None', '1-2', '3-4', '5 or more']

# %%
islam_df = column_select(BDHS_14, islam)
islam_df = islam_df.loc[:, ~islam_df.columns.duplicated()]
islam_df['ha40'] = pd.to_numeric(islam_df['ha40'], errors='coerce')
islam_df['label'] = pd.cut(islam_df['ha40'], bins=bins, labels=labels, right=False)
islam_df['v012'] = pd.cut(islam_df['v012'], bins=age_bins, labels=age_labels, right=False)
#islam_df['hv270'] = pd.cut(islam_df['hv270'], bins=wealth_bins, labels=wealth_labels, right=False)
islam_df['v201'] = pd.cut(islam_df['v201'], bins=children_bins, labels=children_labels, right=False)


threshold = int(0.3 * len(islam_df.columns))
islam_df.dropna(thresh=threshold, inplace=True)

islam_df = islam_df[islam_df['label'].notna()]
islam_df = islam_df.drop('ha40', axis=1)
print(islam_df)
# Out:
#        v012   v025    hv270          v106 v404 v714          v213       v201  \
# 1     20-29  rural   middle  no education   no  yes  no or unsure        3-4
# 7     20-29  rural  poorest       primary  yes   no  no or unsure        3-4
# 10    20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 11    20-29  rural  poorest     secondary  yes   no  no or unsure        3-4
# 21    40-49  rural  poorest  no education   no  yes  no or unsure  5 or more
# 26    20-29  rural   poorer     secondary   no   no           yes        1-2
# 29    30-39  rural  poorest  no education  yes   no  no or unsure  5 or more
# 35    40-49  rural   middle     secondary   no   no  no or unsure  5 or more
# 38    20-29  rural   poorer        higher   no   no  no or unsure        1-2
# 42    30-39  rural  poorest       primary   no   no  no or unsure        3-4
# 44    20-29  rural   poorer       primary   no   no  no or unsure        3-4
# 47    20-29  rural   poorer  no education  yes   no  no or unsure        3-4
# 50    30-39  rural   poorer       primary  yes   no  no or unsure        3-4
# 53    40-49  rural   middle       primary   no  yes  no or unsure  5 or more
# 57    30-39  rural   poorer       primary   no   no  no or unsure        3-4
# 60    20-29  rural  poorest       primary  yes   no  no or unsure        1-2
# 68    20-29  rural   poorer       primary  yes  yes  no or unsure  5 or more
# 72    20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 79    20-29  rural   middle     secondary  yes   no  no or unsure        3-4
# 82    15-19  rural  poorest       primary  yes   no  no or unsure        1-2
# 86    30-39  rural   middle       primary   no   no  no or unsure  5 or more
# 99    40-49  rural   richer       primary   no   no  no or unsure  5 or more
# 102   30-39  rural   poorer       primary   no   no  no or unsure        3-4
# 105   20-29  rural   middle     secondary  yes   no  no or unsure        3-4
# 112   20-29  rural   middle       primary   no   no  no or unsure  5 or more
# 115   20-29  rural  poorest     secondary  yes   no  no or unsure        1-2
# 126   20-29  rural   middle        higher   no   no  no or unsure        1-2
# 128   20-29  rural   poorer     secondary   no   no  no or unsure        1-2
# 134   30-39  rural  poorest     secondary   no   no  no or unsure        3-4
# 137   20-29  rural   poorer     secondary   no   no  no or unsure        3-4
# 141   20-29  rural  poorest       primary   no   no           yes        3-4
# 145   20-29  rural  richest     secondary  yes   no  no or unsure        3-4
# 153   15-19  rural   middle     secondary  yes   no  no or unsure        1-2
# 158   20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 165   15-19  rural   middle     secondary  yes   no  no or unsure        1-2
# 169   30-39  rural  poorest        higher  yes  yes  no or unsure        3-4
# 173   20-29  rural   middle        higher  yes   no  no or unsure        3-4
# 176   15-19  rural   poorer       primary   no   no  no or unsure        1-2
# 182   30-39  rural   poorer       primary  yes   no  no or unsure  5 or more
# 186   15-19  rural   richer       primary  yes   no  no or unsure        3-4
# 191   20-29  rural  poorest     secondary   no   no  no or unsure        3-4
# 194   20-29  rural   richer       primary   no   no           yes        3-4
# 198   20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 202   15-19  rural   middle       primary   no   no  no or unsure        1-2
# 208   30-39  rural   middle       primary  yes   no  no or unsure  5 or more
# 219   40-49  rural  poorest     secondary   no   no  no or unsure  5 or more
# 225   30-39  rural   poorer  no education   no  yes  no or unsure  5 or more
# 229   30-39  rural   middle  no education  yes  yes  no or unsure  5 or more
# 232   20-29  rural   poorer       primary   no   no  no or unsure        3-4
# 236   15-19  rural   poorer     secondary   no   no  no or unsure        1-2
# 241   15-19  rural   poorer     secondary   no   no  no or unsure        1-2
# 249   30-39  rural   richer       primary   no   no  no or unsure  5 or more
# 255   20-29  rural   poorer  no education  yes   no  no or unsure        3-4
# 262   20-29  rural   richer     secondary  yes   no  no or unsure        3-4
# 273   20-29  rural  poorest       primary  yes   no  no or unsure        3-4
# 278   40-49  rural   poorer       primary   no   no  no or unsure  5 or more
# 283   20-29  rural   poorer       primary  yes   no  no or unsure        3-4
# 288   15-19  rural  poorest       primary  yes   no  no or unsure        1-2
# 292   15-19  rural  poorest     secondary  yes   no  no or unsure        1-2
# 298   20-29  rural  poorest       primary  yes   no  no or unsure        3-4
# 303   20-29  rural   poorer     secondary   no   no           yes        1-2
# 305   20-29  rural   richer       primary  yes   no  no or unsure        1-2
# 309   30-39  rural   middle  no education   no   no  no or unsure  5 or more
# 312   20-29  rural   middle  no education  yes   no  no or unsure  5 or more
# 315   20-29  rural   poorer       primary   no   no  no or unsure        3-4
# 321   30-39  rural   richer     secondary   no   no  no or unsure  5 or more
# 329   30-39  rural   richer  no education  yes   no  no or unsure  5 or more
# 337   20-29  rural  poorest       primary   no   no  no or unsure        3-4
# 343   15-19  rural   poorer     secondary  yes   no  no or unsure        1-2
# 346   30-39  rural   poorer  no education   no   no  no or unsure        3-4
# 348   20-29  rural   middle  no education   no   no  no or unsure        3-4
# 354   15-19  rural   middle     secondary  yes   no  no or unsure        1-2
# 360   20-29  rural   middle     secondary  yes   no  no or unsure        3-4
# 363   20-29  rural   middle        higher  yes   no  no or unsure        1-2
# 368   15-19  rural   poorer  no education  yes  yes  no or unsure        3-4
# 370   20-29  rural   middle       primary  yes   no  no or unsure        3-4
# 372   20-29  rural  richest       primary  yes   no  no or unsure        1-2
# 375   20-29  rural   richer       primary  yes   no  no or unsure        1-2
# 383   15-19  rural   middle     secondary  yes  yes  no or unsure        1-2
# 394   20-29  rural   middle       primary   no   no  no or unsure        1-2
# 397   20-29  rural   richer     secondary  yes   no  no or unsure        3-4
# 401   20-29  rural   poorer     secondary  yes   no  no or unsure        1-2
# 405   30-39  rural   richer       primary  yes  yes  no or unsure  5 or more
# 410   15-19  rural  poorest       primary  yes   no           yes        1-2
# 413   15-19  rural   poorer     secondary  yes   no  no or unsure        1-2
# 417   20-29  rural   poorer     secondary   no   no  no or unsure        1-2
# 424   20-29  rural   poorer       primary  yes   no  no or unsure        3-4
# 427   15-19  rural   poorer     secondary  yes  yes  no or unsure        1-2
# 430   20-29  rural   poorer       primary  yes   no  no or unsure  5 or more
# 434   30-39  rural  poorest     secondary   no   no  no or unsure  5 or more
# 442   15-19  rural  poorest        higher  yes   no  no or unsure        1-2
# 449   30-39  rural   poorer       primary   no  yes  no or unsure        3-4
# 456   20-29  rural  poorest     secondary  yes   no  no or unsure        3-4
# 460   20-29  rural   poorer     secondary  yes   no  no or unsure  5 or more
# 471   30-39  rural   poorer       primary   no   no           yes        3-4
# 474   15-19  rural   middle     secondary  yes  yes  no or unsure        1-2
# 485   30-39  rural   middle     secondary   no  yes  no or unsure        3-4
# 493   20-29  rural   richer     secondary  yes  yes  no or unsure        1-2
# 495   20-29  rural   poorer       primary   no  yes  no or unsure        1-2
# 500   30-39  rural  poorest     secondary   no   no  no or unsure        3-4
# 505   30-39  rural   richer       primary  yes  yes  no or unsure        3-4
# 517   30-39  rural   richer       primary  yes   no  no or unsure  5 or more
# 519   30-39  rural   middle       primary  yes   no  no or unsure        3-4
# 521   20-29  rural   middle       primary  yes   no  no or unsure        3-4
# 525   15-19  rural   middle     secondary  yes   no  no or unsure        3-4
# 536   20-29  rural   middle     secondary  yes   no  no or unsure        3-4
# 549   20-29  rural  poorest       primary  yes   no  no or unsure        3-4
# 557   20-29  rural  poorest     secondary   no   no  no or unsure        1-2
# 560   15-19  rural  poorest     secondary  yes   no  no or unsure        1-2
# 563   30-39  rural  poorest  no education  yes   no  no or unsure        3-4
# 568   30-39  rural   poorer       primary   no   no  no or unsure  5 or more
# 571   30-39  rural   poorer     secondary   no   no  no or unsure  5 or more
# 578   20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 584   30-39  rural  poorest       primary   no   no  no or unsure  5 or more
# 586   20-29  rural   poorer       primary  yes   no  no or unsure        3-4
# 589   20-29  rural   poorer     secondary  yes  yes  no or unsure        1-2
# 593   20-29  rural  poorest     secondary   no   no  no or unsure        1-2
# 597   30-39  rural   middle       primary  yes  yes  no or unsure  5 or more
# 601   15-19  rural   poorer     secondary  yes  yes  no or unsure        1-2
# 606   30-39  rural   poorer       primary  yes  yes  no or unsure  5 or more
# 608   20-29  rural  poorest     secondary  yes   no  no or unsure        3-4
# 614   20-29  rural   poorer       primary  yes   no  no or unsure        3-4
# 618   20-29  rural  poorest     secondary  yes   no  no or unsure        3-4
# 627   20-29  rural  poorest        higher   no   no  no or unsure        1-2
# 630   15-19  rural   poorer     secondary  yes   no  no or unsure        1-2
# 635   15-19  rural   middle       primary  yes   no  no or unsure        1-2
# 637   30-39  rural  poorest     secondary  yes   no  no or unsure  5 or more
# 640   20-29  rural  poorest       primary   no   no  no or unsure  5 or more
# 648   15-19  urban   poorer     secondary  yes   no  no or unsure        1-2
# 654   20-29  urban  poorest     secondary   no   no  no or unsure        3-4
# 661   15-19  urban  poorest        higher  yes   no  no or unsure        1-2
# 666   20-29  urban  poorest       primary   no   no  no or unsure        1-2
# 669   30-39  urban  poorest       primary  yes   no  no or unsure        3-4
# 675   20-29  urban   poorer     secondary  yes   no  no or unsure        3-4
# 682   20-29  urban  poorest        higher  yes   no  no or unsure        3-4
# 687   20-29  urban   poorer     secondary   no   no  no or unsure        1-2
# 689   20-29  urban   poorer       primary   no   no  no or unsure        3-4
# 695   20-29  urban   richer     secondary  yes   no  no or unsure        3-4
# 704   20-29  urban   poorer     secondary  yes   no  no or unsure        3-4
# 708   20-29  urban   poorer     secondary   no   no           yes  5 or more
# 711   20-29  urban   poorer     secondary  yes   no  no or unsure        1-2
# 716   20-29  urban  poorest     secondary   no   no  no or unsure        3-4
# 722   15-19  urban   poorer     secondary  yes   no  no or unsure        1-2
# 726   20-29  urban   middle       primary  yes   no  no or unsure        3-4
# 731   15-19  urban   poorer     secondary  yes   no  no or unsure        1-2
# 736   15-19  urban   richer       primary  yes   no  no or unsure        3-4
# 738   30-39  urban   poorer     secondary  yes   no  no or unsure        3-4
# 741   20-29  urban   poorer     secondary  yes   no  no or unsure        3-4
# 746   20-29  urban  poorest        higher   no   no  no or unsure        1-2
# 750   20-29  urban   richer        higher  yes   no  no or unsure        3-4
# 751   20-29  urban   poorer        higher  yes   no  no or unsure        3-4
# 755   20-29  urban  poorest     secondary   no   no  no or unsure        3-4
# 759   20-29  urban   poorer        higher   no   no  no or unsure        3-4
# 761   20-29  urban  poorest       primary  yes  yes  no or unsure        3-4
# 771   20-29  urban  poorest       primary  yes   no  no or unsure        3-4
# 777   20-29  urban  poorest       primary  yes   no  no or unsure        3-4
# 783   20-29  urban   middle     secondary   no   no  no or unsure        3-4
# 788   20-29  urban   poorer     secondary  yes   no  no or unsure        3-4
# 789   15-19  urban   poorer     secondary  yes   no  no or unsure        1-2
# 793   20-29  urban   poorer       primary  yes   no  no or unsure        3-4
# 801   20-29  urban   middle     secondary  yes   no  no or unsure        3-4
# 807   20-29  urban  poorest     secondary  yes   no  no or unsure  5 or more
# 808   20-29  urban   middle       primary   no   no  no or unsure        3-4
# 812   20-29  urban   richer       primary   no   no  no or unsure        1-2
# 813   20-29  urban   poorer     secondary  yes   no  no or unsure        1-2
# 816   30-39  urban   middle       primary  yes   no  no or unsure  5 or more
# 819   20-29  urban   richer     secondary   no   no  no or unsure        1-2
# 822   20-29  urban   richer        higher  yes  yes  no or unsure        3-4
# 824   20-29  urban   richer       primary   no   no  no or unsure        3-4
# 833   20-29  urban   richer       primary   no  yes           yes        3-4
# 839   20-29  urban  poorest     secondary   no   no  no or unsure        1-2
# 842   20-29  urban   middle     secondary  yes   no  no or unsure        1-2
# 844   20-29  urban   middle        higher   no  yes  no or unsure        3-4
# 850   30-39  urban   poorer       primary  yes   no  no or unsure        3-4
# 853   20-29  urban   poorer        higher   no   no  no or unsure        1-2
# 855   20-29  urban  poorest       primary   no   no  no or unsure        3-4
# 856   30-39  urban   poorer        higher  yes   no  no or unsure        3-4
# 859   15-19  urban  poorest     secondary  yes   no  no or unsure        1-2
# 865   20-29  urban   poorer       primary   no  yes  no or unsure        3-4
# 867   15-19  urban   poorer     secondary  yes   no  no or unsure        1-2
# 869   20-29  urban   poorer     secondary  yes   no  no or unsure        1-2
# 872   30-39  urban  poorest     secondary  yes   no  no or unsure        3-4
# 877   20-29  urban   middle       primary  yes   no  no or unsure        1-2
# 879   15-19  urban   middle     secondary  yes   no  no or unsure        1-2
# 881   30-39  urban  richest       primary   no  yes  no or unsure  5 or more
# 893   20-29  urban   poorer     secondary  yes   no  no or unsure        3-4
# 898   15-19  urban   middle     secondary  yes   no  no or unsure        1-2
# 900   30-39  urban   poorer     secondary   no   no  no or unsure        3-4
# 902   20-29  urban   poorer        higher   no   no  no or unsure        3-4
# 905   20-29  urban   middle        higher  yes   no  no or unsure        3-4
# 910   20-29  rural   poorer     secondary   no   no  no or unsure        1-2
# 916   20-29  rural   middle     secondary   no   no  no or unsure        3-4
# 1111  20-29  rural   middle       primary  yes   no  no or unsure  5 or more
# 1119  30-39  rural   poorer     secondary   no   no  no or unsure        3-4
# 1122  20-29  rural  poorest       primary   no   no  no or unsure        1-2
# 1130  30-39  rural   poorer       primary   no  yes  no or unsure        3-4
# 1137  15-19  rural   poorer     secondary  yes   no  no or unsure        1-2
# 1140  20-29  rural   poorer     secondary   no   no  no or unsure        3-4
# 1142  15-19  rural   poorer        higher  yes   no  no or unsure        3-4
# 1148  20-29  rural   middle     secondary   no   no           yes        1-2
# 1151  20-29  rural   middle     secondary  yes   no  no or unsure        3-4
# 1159  20-29  rural  poorest     secondary   no   no  no or unsure        1-2
# 1163  15-19  rural   poorer  no education  yes   no  no or unsure        1-2
# 1165  20-29  rural  poorest     secondary  yes   no  no or unsure        1-2
# 1171  30-39  rural   poorer       primary   no   no  no or unsure  5 or more
# 1175  20-29  rural  poorest       primary  yes   no  no or unsure        3-4
# 1181  20-29  rural   poorer     secondary   no   no  no or unsure        3-4
# 1186  15-19  rural   poorer     secondary  yes   no  no or unsure        1-2
# 1189  20-29  rural   middle       primary  yes   no  no or unsure        3-4
# 1192  20-29  rural  poorest     secondary  yes   no  no or unsure        3-4
# 1196  20-29  rural   middle     secondary  yes   no  no or unsure        3-4
# 1202  30-39  rural   middle     secondary   no   no  no or unsure  5 or more
# 1207  20-29  rural   middle     secondary  yes   no  no or unsure        1-2
# 1211  20-29  rural   richer     secondary   no   no  no or unsure        3-4
# 1217  20-29  rural   middle       primary  yes  yes  no or unsure        3-4
# 1224  20-29  rural   poorer     secondary  yes   no  no or unsure        1-2
# 1229  30-39  rural   richer     secondary  yes  yes  no or unsure        3-4
# 1234  20-29  rural   poorer     secondary   no   no  no or unsure        3-4
# 1241  20-29  rural   poorer       primary  yes   no  no or unsure        3-4
# 1247  20-29  rural   middle     secondary  yes   no  no or unsure        3-4
# 1257  20-29  rural  poorest        higher   no   no           yes        3-4
# 1263  15-19  rural  poorest     secondary  yes   no  no or unsure        1-2
# 1269  15-19  rural  poorest     secondary  yes   no  no or unsure        1-2
# 1274  20-29  rural   middle     secondary   no   no  no or unsure        3-4
# 1285  15-19  rural   poorer     secondary  yes   no  no or unsure        1-2
# 1286  30-39  rural   poorer  no education   no   no  no or unsure  5 or more
# 1290  30-39  rural   richer     secondary   no  yes  no or unsure        3-4
# 1291  30-39  rural  poorest       primary  yes  yes  no or unsure        3-4
# 1295  20-29  rural   poorer     secondary   no   no  no or unsure  5 or more
# 1298  20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 1303  20-29  rural   poorer       primary  yes   no  no or unsure  5 or more
# 1307  20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 1316  30-39  rural   richer     secondary  yes   no  no or unsure  5 or more
# 1318  15-19  rural   middle        higher  yes   no  no or unsure        1-2
# 1323  20-29  rural   poorer  no education   no   no  no or unsure  5 or more
# 1327  20-29  rural   middle     secondary   no   no  no or unsure        3-4
# 1330  20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 1339  30-39  rural   poorer       primary   no   no  no or unsure        3-4
# 1342  30-39  rural   middle        higher   no   no  no or unsure        3-4
# 1344  20-29  rural   poorer        higher  yes   no  no or unsure        3-4
# 1351  20-29  rural   richer  no education   no   no  no or unsure        3-4
# 1355  20-29  rural   richer     secondary   no   no           yes        1-2
# 1356  15-19  rural  poorest     secondary  yes   no  no or unsure        1-2
# 1365  20-29  rural   middle       primary  yes   no  no or unsure        3-4
# 1368  20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 1370  30-39  rural  poorest     secondary  yes  yes  no or unsure  5 or more
# 1375  30-39  rural   poorer       primary  yes  yes  no or unsure  5 or more
# 1379  20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 1385  20-29  rural   richer        higher   no  yes  no or unsure        3-4
# 1387  20-29  rural   richer     secondary   no  yes           yes        3-4
# 1390  20-29  rural   middle     secondary  yes  yes  no or unsure        3-4
# 1391  20-29  rural   middle     secondary   no   no  no or unsure        3-4
# 1394  20-29  rural  poorest     secondary  yes   no  no or unsure        3-4
# 1406  20-29  rural   poorer     secondary   no   no  no or unsure        3-4
# 1411  20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 1413  20-29  rural   middle     secondary  yes   no  no or unsure        3-4
# 1415  40-49  rural   richer       primary   no  yes  no or unsure  5 or more
# 1418  20-29  rural   richer       primary   no   no           yes        3-4
# 1421  20-29  rural   poorer     secondary   no   no  no or unsure        1-2
# 1422  20-29  rural  poorest     secondary  yes  yes  no or unsure        3-4
# 1424  20-29  rural   poorer        higher   no  yes  no or unsure        3-4
# 1429  30-39  rural   poorer     secondary   no   no  no or unsure        3-4
# 1435  30-39  rural  richest     secondary   no   no  no or unsure  5 or more
# 1439  20-29  rural   richer     secondary  yes   no  no or unsure        3-4
# 1444  20-29  rural   richer     secondary  yes   no  no or unsure        3-4
# 1446  20-29  rural   middle     secondary   no   no           yes        1-2
# 1451  15-19  rural  richest     secondary  yes   no  no or unsure        1-2
# 1455  20-29  rural   middle     secondary   no   no  no or unsure        3-4
# 1458  15-19  rural  richest     secondary  yes   no  no or unsure        1-2
# 1463  20-29  rural  richest     secondary   no   no  no or unsure        3-4
# 1466  15-19  rural   richer     secondary  yes   no  no or unsure        1-2
# 1470  30-39  rural   richer       primary  yes   no  no or unsure  5 or more
# 1473  20-29  rural   richer     secondary   no   no  no or unsure        3-4
# 1476  15-19  rural  richest     secondary  yes   no  no or unsure        1-2
# 1481  20-29  rural   richer        higher  yes   no  no or unsure        1-2
# 1487  20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 1493  15-19  rural  poorest       primary   no  yes  no or unsure        1-2
# 1497  20-29  rural   middle     secondary   no   no  no or unsure        1-2
# 1502  20-29  rural  richest     secondary   no   no  no or unsure        1-2
# 1508  30-39  rural   middle       primary   no   no  no or unsure  5 or more
# 1512  15-19  rural   richer     secondary  yes  yes  no or unsure        3-4
# 1945  20-29  urban   middle       primary  yes   no  no or unsure        1-2
# 1949  15-19  urban   middle       primary  yes   no  no or unsure        3-4
# 1955  15-19  urban   richer       primary  yes   no  no or unsure        1-2
# 1956  30-39  urban  richest       primary   no   no  no or unsure  5 or more
# 1960  20-29  urban   richer     secondary   no   no  no or unsure        3-4
# 1966  20-29  urban  richest     secondary  yes   no  no or unsure        1-2
# 1972  20-29  urban   richer        higher  yes   no  no or unsure        3-4
# 1977  20-29  urban  richest     secondary   no   no  no or unsure        3-4
# 1984  20-29  urban   richer     secondary   no   no  no or unsure        3-4
# 1988  20-29  urban  richest     secondary   no   no  no or unsure        3-4
# 1995  30-39  urban  richest  no education   no  yes  no or unsure  5 or more
# 2001  20-29  urban  richest        higher   no  yes  no or unsure        3-4
# 2005  20-29  urban  richest     secondary   no   no  no or unsure        3-4
# 2010  20-29  urban   richer     secondary  yes   no  no or unsure        3-4
# 2017  30-39  urban   richer     secondary   no   no  no or unsure  5 or more
# 2022  20-29  urban   middle       primary   no   no  no or unsure        3-4
# 2024  20-29  urban   middle        higher   no  yes  no or unsure        3-4
# 2031  20-29  urban   richer       primary  yes   no  no or unsure        3-4
# 2034  20-29  urban   richer       primary  yes   no  no or unsure        3-4
# 2039  20-29  urban  richest     secondary   no  yes  no or unsure        3-4
# 2043  15-19  urban   middle     secondary  yes  yes  no or unsure        1-2
# 2049  15-19  urban  richest     secondary  yes   no  no or unsure        1-2
# 2058  20-29  urban  richest       primary  yes   no  no or unsure        1-2
# 2072  20-29  urban   poorer     secondary   no   no  no or unsure        1-2
# 2074  30-39  urban   richer       primary   no   no  no or unsure  5 or more
# 2078  20-29  urban   richer       primary  yes   no  no or unsure        3-4
# 2080  15-19  urban  richest     secondary   no  yes  no or unsure        1-2
# 2084  30-39  urban   middle  no education   no  yes  no or unsure  5 or more
# 2090  20-29  urban   poorer     secondary  yes   no  no or unsure        3-4
# 2094  20-29  urban  poorest  no education  yes   no  no or unsure        3-4
# 2097  20-29  urban   richer       primary   no   no  no or unsure        3-4
# 2101  20-29  urban   richer       primary  yes   no  no or unsure        1-2
# 2105  20-29  urban  richest       primary  yes   no  no or unsure        3-4
# 2115  15-19  urban  richest     secondary  yes   no  no or unsure        1-2
# 2117  30-39  urban   richer     secondary   no   no  no or unsure        1-2
# 2123  15-19  urban  poorest     secondary  yes   no  no or unsure        3-4
# 2131  15-19  urban   middle       primary  yes   no  no or unsure        1-2
# 2133  20-29  urban   middle     secondary   no   no  no or unsure        3-4
# 2139  30-39  urban   middle       primary  yes   no  no or unsure        3-4
# 2147  15-19  urban  richest     secondary  yes   no  no or unsure        1-2
# 2152  30-39  urban   poorer     secondary  yes   no  no or unsure  5 or more
# 2156  20-29  urban   richer        higher   no   no  no or unsure        3-4
# 2158  30-39  urban   middle       primary  yes   no  no or unsure  5 or more
# 2160  20-29  urban   middle     secondary   no  yes  no or unsure        3-4
# 2165  20-29  urban   middle        higher  yes  yes  no or unsure        3-4
# 2437  30-39  rural   richer       primary  yes   no  no or unsure  5 or more
# 2442  15-19  rural   richer  no education  yes   no  no or unsure        3-4
# 2446  15-19  rural  poorest     secondary   no   no  no or unsure        1-2
# 2450  20-29  rural   richer     secondary   no   no  no or unsure        1-2
# 2453  20-29  rural   middle     secondary  yes   no  no or unsure        1-2
# 2457  20-29  rural   middle  no education  yes   no  no or unsure        3-4
# 2459  20-29  rural   poorer       primary   no   no  no or unsure        1-2
# 2463  30-39  rural   richer  no education   no   no  no or unsure        3-4
# 2471  20-29  rural   middle        higher   no   no           yes        1-2
# 2475  20-29  rural  poorest        higher   no   no  no or unsure        1-2
# 2478  30-39  rural   richer        higher   no   no  no or unsure        3-4
# 2482  30-39  rural  poorest        higher   no   no  no or unsure        3-4
# 2485  15-19  rural   poorer       primary   no  yes  no or unsure        1-2
# 2490  20-29  rural   richer     secondary   no   no  no or unsure        1-2
# 2495  20-29  rural  richest     secondary  yes   no  no or unsure        3-4
# 2507  20-29  rural   middle       primary   no  yes           yes        1-2
# 2509  30-39  rural   middle  no education  yes  yes  no or unsure        3-4
# 2511  20-29  rural   richer     secondary   no  yes  no or unsure        3-4
# 2517  15-19  rural   richer       primary  yes   no  no or unsure        1-2
# 2522  20-29  rural   richer     secondary   no   no  no or unsure        3-4
# 2527  20-29  rural   poorer        higher   no   no           yes        1-2
# 2531  15-19  rural   middle       primary   no  yes  no or unsure        1-2
# 2536  20-29  rural   poorer     secondary  yes   no  no or unsure        1-2
# 2541  20-29  rural  richest       primary  yes   no  no or unsure        3-4
# 2546  20-29  rural   poorer     secondary  yes   no  no or unsure        1-2
# 2552  20-29  rural  richest     secondary  yes  yes  no or unsure  5 or more
# 2553  20-29  rural   middle     secondary  yes  yes  no or unsure  5 or more
# 2557  30-39  rural   middle     secondary  yes   no  no or unsure        3-4
# 2558  20-29  rural   middle     secondary  yes   no  no or unsure        3-4
# 2563  15-19  rural   middle        higher  yes   no  no or unsure        1-2
# 2565  15-19  rural   richer     secondary  yes   no  no or unsure        1-2
# 2570  30-39  rural   richer       primary  yes  yes  no or unsure        3-4
# 2575  30-39  rural  richest     secondary   no  yes  no or unsure  5 or more
# 2585  20-29  rural   middle  no education   no   no  no or unsure        3-4
# 2586  30-39  rural  richest  no education  yes  yes  no or unsure  5 or more
# 2591  40-49  rural  richest     secondary   no  yes  no or unsure        3-4
# 2599  20-29  rural  richest     secondary  yes   no  no or unsure        3-4
# 2605  20-29  rural  richest     secondary  yes   no  no or unsure        1-2
# 2609  40-49  rural   poorer       primary  yes   no  no or unsure  5 or more
# 2619  20-29  rural  poorest     secondary   no   no  no or unsure  5 or more
# 2624  20-29  rural   poorer     secondary  yes  yes  no or unsure        3-4
# 2629  20-29  rural   poorer  no education   no  yes  no or unsure        3-4
# 2634  20-29  rural   middle     secondary   no  yes  no or unsure        3-4
# 2636  15-19  rural   richer     secondary  yes   no  no or unsure        1-2
# 2640  15-19  rural  poorest       primary  yes  yes  no or unsure        1-2
# 2646  20-29  rural   middle     secondary   no  yes  no or unsure        1-2
# 2661  20-29  rural   richer     secondary   no   no           yes  5 or more
# 2666  15-19  rural   richer       primary   no   no           yes        1-2
# 2670  20-29  rural   middle       primary   no  yes  no or unsure  5 or more
# 2673  30-39  rural   poorer  no education  yes   no  no or unsure  5 or more
# 2679  20-29  rural   middle       primary  yes   no           yes        3-4
# 2682  30-39  rural  richest  no education  yes   no  no or unsure  5 or more
# 2690  30-39  rural   richer  no education  yes   no  no or unsure  5 or more
# 2693  20-29  rural   poorer       primary  yes   no  no or unsure        3-4
# 2695  20-29  rural   middle     secondary   no   no  no or unsure        1-2
# 2700  30-39  rural   richer       primary  yes   no  no or unsure  5 or more
# 2704  20-29  rural   richer     secondary  yes   no  no or unsure        3-4
# 2705  20-29  rural   richer     secondary  yes   no  no or unsure        3-4
# 2710  30-39  rural  richest  no education  yes   no  no or unsure  5 or more
# 2716  20-29  rural   middle       primary  yes   no  no or unsure        3-4
# 2719  30-39  rural   middle  no education  yes   no  no or unsure  5 or more
# 2723  20-29  rural   middle     secondary  yes   no  no or unsure        1-2
# 2726  20-29  rural   richer       primary   no   no  no or unsure        1-2
# 2734  20-29  rural   middle  no education  yes  yes  no or unsure  5 or more
# 2755  20-29  rural   poorer     secondary   no   no  no or unsure        3-4
# 2758  20-29  rural   poorer     secondary   no  yes  no or unsure        1-2
# 2764  20-29  rural  richest       primary  yes   no  no or unsure        3-4
# 2772  15-19  rural   middle     secondary  yes   no  no or unsure        1-2
# 2780  20-29  rural  richest       primary  yes   no  no or unsure        1-2
# 2783  20-29  rural   poorer     secondary   no   no  no or unsure        1-2
# 2788  30-39  rural   middle        higher  yes   no  no or unsure        1-2
# 2791  20-29  rural   middle     secondary   no   no  no or unsure        3-4
# 2796  20-29  rural   middle       primary   no   no  no or unsure        1-2
# 2802  15-19  rural  poorest     secondary   no   no  no or unsure        1-2
# 2805  15-19  rural   poorer     secondary  yes   no  no or unsure        1-2
# 2812  30-39  rural   richer     secondary   no  yes  no or unsure        3-4
# 2820  30-39  rural   middle     secondary  yes   no  no or unsure        3-4
# 2823  30-39  rural   middle  no education  yes  yes  no or unsure  5 or more
# 2829  30-39  rural   richer  no education  yes  yes  no or unsure  5 or more
# 2835  40-49  rural   richer  no education   no  yes  no or unsure  5 or more
# 2836  20-29  rural   middle     secondary   no  yes  no or unsure        3-4
# 2842  15-19  rural   middle       primary  yes   no  no or unsure        1-2
# 2848  20-29  rural   poorer     secondary  yes   no  no or unsure        3-4
# 2854  15-19  rural   richer     secondary  yes  yes  no or unsure        1-2
# 2856  30-39  rural   middle     secondary  yes  yes  no or unsure        3-4
# 2861  30-39  rural   middle     secondary  yes  yes  no or unsure  5 or more
# 2863  20-29  rural  richest       primary   no  yes  no or unsure        3-4
# 2866  20-29  rural   richer     secondary  yes   no  no or unsure  5 or more
# 2870  20-29  rural  richest       primary   no  yes  no or unsure        1-2
# 2871  30-39  rural   poorer       primary  yes   no  no or unsure        3-4
# 2877  30-39  rural  poorest     secondary  yes   no  no or unsure        3-4
# 2887  30-39  rural   richer       primary  yes  yes  no or unsure  5 or more
# 2890  15-19  rural  richest     secondary  yes   no  no or unsure        1-2
# 2896  40-49  rural   middle  no education   no   no           yes        1-2
# ...
# 6266                   wood       normal
# 6268      agricultural crop  underweight
# 6271                   wood  underweight
# 6277      agricultural crop        obese
# 6279      agricultural crop       normal
# 6281      agricultural crop        obese
# 6282      agricultural crop        obese
# 6287      agricultural crop       normal
# 6289      agricultural crop       normal
# 6296      agricultural crop       normal
# 6305      agricultural crop       normal
# 6309      agricultural crop       normal
# 6310      agricultural crop       normal
# 6315      agricultural crop       normal
# 6321      agricultural crop       normal
# 6323      agricultural crop       normal
# 6326      agricultural crop       normal
# 6328                   wood  underweight
# 6332      agricultural crop       normal
# 6334      agricultural crop  underweight
# 6337      agricultural crop       normal
# 6338      agricultural crop  underweight
# 6348            electricity  underweight
# 6352                   wood       normal
# 6357      agricultural crop       normal
# 6361                   wood       normal
# 6365                   wood  underweight
# 6370                   wood       normal
# 6374                   wood  underweight
# 6380                   wood       normal
# 6388                   wood  underweight
# 6392      agricultural crop  underweight
# 6393      agricultural crop  underweight
# 6398      agricultural crop        obese
# 6399  not a dejure resident       normal
# 6404            animal dung       normal
# 6409      agricultural crop  underweight
# 6414      agricultural crop  underweight
# 6417                   wood       normal
# 6419                   wood       normal
# 6425                   wood       normal
# 6431  not a dejure resident        obese
# 6437                   wood       normal
# 6438                   wood       normal
# 6443      agricultural crop        obese
# 6445                   wood  underweight
# 6448                   wood       normal
# 6456                   wood       normal
# 6458                   wood       normal
# 6460      agricultural crop       normal
# 6472                   wood  underweight
# 6481                   wood       normal
# 6495                   wood       normal
# 6499                   wood       normal
# 6502                   wood       normal
# 6504                   wood  underweight
# 6507                   wood       normal
# 6512                   wood  underweight
# 6515                   wood       normal
# 6518                   wood       normal
# 6519                   wood       normal
# 6523      agricultural crop       normal
# 6529                    lpg       normal
# 6533                   wood       normal
# 6535  not a dejure resident        obese
# 6536                   wood       normal
# 6541                   wood       normal
# 6545      agricultural crop        obese
# 6549  not a dejure resident       normal
# 6553                   wood  underweight
# 6559      agricultural crop       normal
# 6561                   wood       normal
# 6567                   wood       normal
# 6569      agricultural crop  underweight
# 6573                   wood       normal
# 6578                   wood        obese
# 6582                   wood       normal
# 6590  not a dejure resident  underweight
# 6594                   wood       normal
# 6595                   wood       normal
# 6598            animal dung       normal
# 6602            animal dung  underweight
# 6606            animal dung        obese
# 6609                   wood       normal
# 6613  not a dejure resident       normal
# 6616                   wood       normal
# 6619                   wood       normal
# 6624  not a dejure resident  underweight
# 6631                   wood  underweight
# 6635                   wood       normal
# 6638                   wood       normal
# 6641                   wood       normal
# 6647                   wood       normal
# 6651                   wood        obese
# 6652     straw/shrubs/grass       normal
# 6655                   wood       normal
# 6662                   wood       normal
# 6664                   wood       normal
# 6666      agricultural crop       normal
# 6669                   wood       normal
# 6674                   wood       normal
# 6676      agricultural crop       normal
# 6678                   wood        obese
# 6683                   wood       normal
# 6695            animal dung       normal
# 6698                   wood       normal
# 6703            animal dung  underweight
# 6713                   wood       normal
# 6717                   wood  underweight
# 6726  not a dejure resident  underweight
# 6731                   wood       normal
# 6734                   wood  underweight
# 6740            animal dung  underweight
# 6743            animal dung  underweight
# 6746                   wood        obese
# 6752                   wood       normal
# 6756                   wood       normal
# 6761                   wood        obese
# 6765                   wood       normal
# 6769                   wood       normal
# 6775                   wood       normal
# 6782                   wood        obese
# 6783                   wood       normal
# 6787      agricultural crop        obese
# 6795                   wood  underweight
# 6800                   wood        obese
# 6801                   wood       normal
# 6804                   wood       normal
# 6809                   wood       normal
# 6813                   wood        obese
# 6819                   wood       normal
# 6822                   wood       normal
# 6826                   wood       normal
# 6828                   wood        obese
# 6833                   wood        obese
# 6838                   wood        obese
# 6841                   wood       normal
# 6845                   wood        obese
# 6851                   wood       normal
# 6859                   wood       normal
# 6864                   wood        obese
# 6867                   wood       normal
# 6872                   wood        obese
# 6875                   wood        obese
# 6880                   wood  underweight
# 6883                   wood       normal
# 6889                   wood       normal
# 6892                   wood       normal
# 6899                   wood        obese
# 6902                   wood        obese
# 6905                   wood        obese
# 6908                   wood        obese
# 6910                   wood       normal
# 6913                   wood       normal
# 6915                   wood        obese
# 6924                   wood       normal
# 6926                   wood  underweight
# 6932                   wood       normal
# 6933                   wood  underweight
# 6937                   wood       normal
# 6939                   wood       normal
# 6943      agricultural crop       normal
# 6948                   wood        obese
# 6951                   wood       normal
# 6954                   wood  underweight
# 6961                   wood        obese
# 6964  not a dejure resident       normal
# 6972                   wood        obese
# 6979                   wood       normal
# 6982                   wood        obese
# 6990                   wood       normal
# 6992                   wood       normal
# 6994            animal dung       normal
# 6998                   wood       normal
# 7005            animal dung       normal
# 7007          coal, lignite       normal
# 7011            animal dung        obese
# 7016            animal dung        obese
# 7018          coal, lignite        obese
# 7021      agricultural crop        obese
# 7031      agricultural crop       normal
# 7038          coal, lignite       normal
# 7043                   wood        obese
# 7047            animal dung        obese
# 7055                   wood       normal
# 7058            animal dung       normal
# 7060                   wood  underweight
# 7061                   wood       normal
# 7063                   wood  underweight
# 7071      agricultural crop        obese
# 7076                   wood       normal
# 7077                   wood       normal
# 7080      agricultural crop  underweight
# 7086  not a dejure resident       normal
# 7089                   wood  underweight
# 7090                   wood       normal
# 7092                   wood       normal
# 7096  not a dejure resident        obese
# 7098                   wood       normal
# 7101                    lpg       normal
# 7104                   wood        obese
# 7106                   wood       normal
# 7111                   wood       normal
# 7113                   wood        obese
# 7116     straw/shrubs/grass        obese
# 7123                   wood        obese
# 7127  not a dejure resident       normal
# 7131                   wood  underweight
# 7133            animal dung  underweight
# 7136  not a dejure resident       normal
# 7137                   wood  underweight
# 7139                   wood        obese
# 7143                   wood        obese
# 7145                   wood  underweight
# 7148            animal dung       normal
# 7153                   wood       normal
# 7161                   wood       normal
# 7164     straw/shrubs/grass       normal
# 7167                   wood        obese
# 7169      agricultural crop       normal
# 7172      agricultural crop       normal
# 7175      agricultural crop       normal
# 7178            animal dung       normal
# 7183      agricultural crop       normal
# 7187      agricultural crop       normal
# 7191                   wood       normal
# 7195      agricultural crop       normal
# 7204                   wood       normal
# 7208                   wood       normal
# 7211                   wood       normal
# 7213                   wood       normal
# 7216                   wood       normal
# 7223                   wood       normal
# 7228                   wood       normal
# 7233                   wood        obese
# 7238                   wood       normal
# 7241                   wood        obese
# 7243                   wood       normal
# 7245                   wood        obese
# 7249                   wood        obese
# 7255                   wood       normal
# 7258                   wood        obese
# 7260                   wood       normal
# 7264                   wood       normal
# 7267                   wood       normal
# 7271                   wood  underweight
# 7276  not a dejure resident       normal
# 7278                   wood  underweight
# 7281                   wood       normal
# 7282                   wood        obese
# 7289                   wood        obese
# 7295                   wood        obese
# 7297                   wood  underweight
# 7301               charcoal       normal
# 7305                   wood       normal
# 7309                   wood       normal
# 7316                   wood        obese
# 7318            animal dung       normal
# 7320  not a dejure resident       normal
# 7330                   wood       normal
# 7336                   wood        obese
# 7340                   wood       normal
# 7345                   wood        obese
# 7350                   wood        obese
# 7353  not a dejure resident        obese
# 7357                   wood        obese
# 7360                   wood        obese
# 7363                   wood        obese
# 7366  not a dejure resident        obese
# 7371                   wood        obese
# 7377                   wood       normal
# 7381                   wood        obese
# 7385                   wood       normal
# 7388                   wood       normal
# 7390                   wood       normal
# 7393                   wood       normal
# 7397                   wood        obese
# 7407                   wood        obese
# 7410                   wood       normal
# 7415                   wood        obese
# 7420                   wood       normal
# 7425                   wood        obese
# 7430                   wood        obese
# 7433                   wood        obese
# 7439                   wood       normal
# 7443                   wood        obese
# 7444                   wood        obese
# 7449                   wood        obese
# 7451                   wood        obese
# 7454                   wood        obese
# 7459                   wood        obese
# 7461                   wood       normal
# 7468                   wood       normal
# 7475                   wood        obese
# 7484                   wood       normal
# 7487  not a dejure resident       normal
# 7492                   wood        obese
# 7501                   wood        obese
# 7506                   wood       normal
# 7512                   wood  underweight
# 7519            natural gas       normal
# 7523            natural gas       normal
# 7532                   wood       normal
# 7535                   wood        obese
# 7539                   wood        obese
# 7545                   wood  underweight
# 7553                   wood  underweight
# 7555                   wood       normal
# 7557                   wood        obese
# 7563            natural gas       normal
# 7568            natural gas        obese
# 7572                   wood       normal
# 7576                   wood       normal
# 7579            natural gas        obese
# 7583                   wood       normal
# 7589                   wood       normal
# 7590                   wood       normal
# 7597                   wood        obese
# 7601                   wood       normal
# 7604            natural gas       normal
# 7609            natural gas       normal
# 7614            natural gas       normal
# 7620               charcoal  underweight
# 7624     straw/shrubs/grass        obese
# 7630                   wood       normal
# 7632            animal dung       normal
# 7636            animal dung       normal
# 7640      agricultural crop       normal
# 7652                   wood  underweight
# 7661                   wood  underweight
# 7665                   wood       normal
# 7667                   wood  underweight
# 7677               charcoal       normal
# 7683                   wood       normal
# 7687                   wood       normal
# 7692                   wood       normal
# 7695                   wood       normal
# 7698      agricultural crop  underweight
# 7702                   wood       normal
# 7705                   wood       normal
# 7708                   wood       normal
# 7718                   wood        obese
# 7722                   wood       normal
# 7727                   wood       normal
# 7739            natural gas       normal
# 7748            natural gas  underweight
# 7753               charcoal       normal
# 7756            natural gas  underweight
# 7764  not a dejure resident       normal
# 7769            natural gas       normal
# 7773            natural gas       normal
# 7788      agricultural crop       normal
# 7792                  other       normal
# 7797                   wood       normal
# 7804            natural gas       normal
# 7809  not a dejure resident        obese
# 7814            natural gas       normal
# 7816            natural gas       normal
# 7819  not a dejure resident       normal
# 7825            natural gas       normal
# 7831            natural gas  underweight
# 7833      agricultural crop  underweight
# 7838            natural gas       normal
# 7842                   wood       normal
# 7846            natural gas        obese
# 7851                   wood       normal
# 7856                   wood       normal
# 7863                   wood        obese
# 7867            natural gas       normal
# 7874            natural gas        obese
# 7879                   wood       normal
# 7884  not a dejure resident       normal

# %%
islam_df.dtypes
# Out:
# v012     category
# v025     category
# hv270    category
# v106     category
# v404     category
# v714     category
# v213     category
# v201     category
# v701     category
# v113     category
# v116     category
# v130     category
# v161     category
# label    category
# dtype: object

# %%
islam_df['v113'].unique()
# Out:
# ['tube well or borehole', 'river/dam/lake/ponds/stream/canal/irrigation ..., 'not a dejure resident', 'public tap/standpipe', 'rainwater', ..., 'piped into dwelling', 'piped to yard/plot', 'bottled water', 'unprotected well', 'unprotected spring']
# Length: 12
# Categories (15, object): ['piped into dwelling' < 'piped to yard/plot' < 'public tap/standpipe' < 'tube well or borehole' ... 'cart with small tank' < 'bottled water' < 'other' < 'not a dejure resident']

# %%
# Define the parameter grid to search over
param_grid = {
    'n_estimators': [500],  # Number of trees in the forest
    'max_depth': [ 8,9, 10, 11,12, None],       # Maximum depth of the tree
    #'min_samples_split': [2, 5, 10],   # Minimum number of samples required to split an internal node
    #'min_samples_leaf': [ 2, 4,8, 16]      # Minimum number of samples required to be at a leaf node
}

# %%
from sklearn.feature_extraction import FeatureHasher


y = islam_df['label']
X = islam_df.drop(['label'], axis=1)

X = X.astype(str)

# Get the indices of the categorical columns
categorical_indices = [i for i, col in enumerate(X.columns) if X[col].dtype.name == 'object']
#print(categorical_indices)

# Define the transformer for one-hot encoding
#ct = ColumnTransformer([('encoder', OneHotEncoder(), categorical_indices)])

# Fit and transform the data
#X_encoded = ct.fit_transform(X)


hasher = FeatureHasher(n_features=10, input_type='string')
X_encoded = hasher.fit_transform(X.values)


# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Further split train set into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2







# Initialize the RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the GridSearchCV instance to the data
grid_search.fit(X_train, y_train)

# Get the best parameters and the best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Predict on the test set
y_pred = grid_search.predict(X_val)

# Calculate accuracy
accuracy = accuracy_score(y_val, y_pred)
print("Accuracy:", accuracy)
# Out:
# Best Parameters: {'max_depth': 8, 'n_estimators': 500}
# Best Score: 0.6081979635330335
# Accuracy: 0.6081871345029239
